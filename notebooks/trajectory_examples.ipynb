# %% [markdown]
# # UAV Trajectory Examples
#
# This notebook displays example UAV trajectories from training at different timesteps.

# %%
from IPython.display import IFrame, HTML
import os

# %% [markdown]
# ## Trajectory at 250,000 steps

# %%
with open('/Users/user/Documents/education/CAI/bachelor_thesis/uav-nav-obstacle-avoidance-rl/reports/examples/UAV_trajectory_0_250000_879b8508a17ebdb4c694.html', 'r') as f:
    html_content = f.read()
HTML(html_content)
# Out:
# <html>
# <head><base target="_blank"><link rel="stylesheet" type="text/css" href="https://app.wandb.ai/normalize.css" /><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Trajectory at 300,000 steps

# %%
with open('/Users/user/Documents/education/CAI/bachelor_thesis/uav-nav-obstacle-avoidance-rl/reports/examples/UAV_trajectory_2_300000_8c445daa54457e7b2f95.html', 'r') as f:
    html_content = f.read()
HTML(html_content)
# Out:
# <html>
# <head><base target="_blank"><link rel="stylesheet" type="text/css" href="https://app.wandb.ai/normalize.css" /><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
